# %%
import pickle

# Load saved model
with open("placement_model.pkl", "rb") as file:
    loaded_model = pickle.load(file)

# New student data
new_student = [[118, 7.2, 0]]  # IQ, CGPA, Backlogs

# Prediction
prediction = loaded_model.predict(new_student)

print("Placement:", "YES" if prediction[0] == 1 else "NO")
# Out:
# Placement: YES
# /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
